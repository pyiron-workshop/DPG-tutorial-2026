# %%
import sys

# %%
path = "/home/jovyan/dpg_tutorial_2026/pyiron_core_data/ai_storage"

# %%
sys.path.insert(0, path)

# %%
path_nodes = "/home/jovyan/dpg_tutorial_2026"

# %%
sys.path.insert(0, path_nodes)

# %%
import pyiron_nodes

# %%
import node_store

# %%
node_store.__file__, pyiron_nodes.__file__
# Out:
# ('/home/jovyan/dpg_tutorial_2026/pyiron_core_data/ai_storage/node_store.py',
#  '/home/jovyan/dpg_tutorial_2026/pyiron_nodes/__init__.py')

# %%
pyiron_nodes_path = pyiron_nodes.__path__[0]
node_store.generate_node_catalog(pyiron_nodes_path, "pyiron_node_catalog.json", update=True, debug=True)
# Out:
# ⚠️  Overwriting existing file /home/jovyan/dpg_tutorial_2026/pyiron_core_data/ai_storage/pyiron_node_catalog.json
# ✅  Found function node: ConvertLoadToStress
# ✅  Found function node: CalculateYoungsModulus
# ✅  Found function node: Plot
# ✅  Found function node: LinePhase
# ✅  Found function node: TemperatureDependentLinePhase
# ✅  Found function node: TransitionTemperature
# ✅  Found function node: IdealSolution
# ✅  Found function node: CalcPhaseDiagram
# ✅  Found function node: PlotConcPhaseDiagram
# ✅  Found function node: PlotMuPhaseDiagram
# ✅  Found function node: PhasesFromDataFrame
# ✅  Found function node: Multiply
# ✅  Found function node: SliceArray
# ✅  Found function node: GetVector
# ✅  Found function node: MinMaxIndices
# ✅  Found function node: Linspace
# ✅  Found function node: ReadCSV
# ✅  Found function node: ReadDataFrame
# ✅  Found function node: DataframeToList
# ✅  Found function node: SingleNodeExecutor
# ✅  Found function node: FluxClusterExecutor
# ...
